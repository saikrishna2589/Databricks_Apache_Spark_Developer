# %% [markdown]
# Create Spark Session builder

# %%
from pyspark.sql import SparkSession

sparkSession =SparkSession.builder.getOrCreate()
 
display(sparkSession.version)

# %% [markdown]
# 2. What is pre-created spark session

# %%
spark.version

# %% [markdown]
# How to use sparksession to read table data

# %%
df = spark.read.table('dev.spark_db.diamonds')

# %%
display(df)

# %%
df.show()

# %%
df.display()
